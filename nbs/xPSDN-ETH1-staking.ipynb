# %%
import pandas as pd
csv_file = "/Users/nvtrang/code/h2o/protocol-liquidity/data/staking_rewards_balances.csv"

xPSDN_ETH1_staking_balances = pd.read_csv(csv_file, index_col=0)
xPSDN_ETH1_staking_balances[["balance"]].apply(pd.to_numeric)

xPSDN_ETH1_staking_balances = xPSDN_ETH1_staking_balances.loc[xPSDN_ETH1_staking_balances["balance"] > 0]
xPSDN_ETH1_staking_balances.sort_values(by=["balance"], ascending=False)
# Out:
#                                         staker     balance
# 10  0x6e1ad8e91b9b7b677c2a81fa31b6faaa657424fb  108.558368
# 2   0xc647f8f745a59b74a26d76da7dccc8badf649c32    4.946120
# 34  0xc148368d792937c649bcfe64ccf101dd6d7d77b4    3.745663
# 17  0x519e21a4bf3eb67d811b04b4d8d44deaba5f5e0a    2.267751
# 27  0xc766d73be01caa06834032bf5c8f8f0f41a7bf36    0.674297
# 6   0xb81a01f609c78c35b95ed5b1c3fd843fc73bdb6f    0.568656
# 3   0xd58dcd4594087c2758717a59f44a5ac09db65105    0.214239
# 15  0x12cdfa0fc53615e2be8d9b495b065c108bf77907    0.180200
# 0   0x62352f1a701cff2aeb6b69d6a8cb196887020f22    0.141089
# 26  0x139776871ee95f55d20b10d9ba5a0385451066cd    0.000492
# 32  0x5a6eade27773eab2e4038ec7cf388781eca02f63    0.000128
